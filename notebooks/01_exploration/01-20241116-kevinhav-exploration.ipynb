# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import flight_numbers.get_data

pd.set_option('display.max_columns', None)
pd.set_option('display.precision', 2)

# %%
pdga = flight_numbers.get_data.get_pdga_data()

# %%
pdga_clean = flight_numbers.get_data.clean_pdga_data(pdga)

# %%
pdga_clean
# Out:
#      manufacturer_/_distributor  \
# 0                   Latitude 64
# 1                   Latitude 64
# 2                Lone Star Disc
# 3                   Yikun Discs
# 4                   Yikun Discs
# ...                         ...
# 2128               Wham-O, Inc.
# 2129               Wham-O, Inc.
# 2130               Wham-O, Inc.
# 2131               Wham-O, Inc.
# 2132               Wham-O, Inc.
#
#                                              disc_model  max_weight_(gr)  \
# 0                                                 Sweep            176.0
# 1                                                  Peak            176.8
# 2                                          Prickly Pear            176.0
# 3                                          Wù Kōng (悟空)            176.0
# 4                                           Bái Zé (白泽)            176.0
# ...                                                 ...              ...
# ...

# %%
df = flight_numbers.get_data.get_data()
# Out:
# /Users/kevinhav/projects/d606_final_project/flight_numbers/get_data.py:41: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_html(str(table))[0]

# %%
df
# Out:
#           disc  speed  glide  turn  fade manufacturer_/_distributor  \
# 0         Aero    3.0      6     0   0.0      Innova Champion Discs
# 1        Alien    4.0      2     0   1.0      Innova Champion Discs
# 2       Animal    2.0      1     0   1.0      Innova Champion Discs
# 3          Ape   13.0      5     0   4.0      Innova Champion Discs
# 4    Archangel    8.0      6    -4   1.0      Innova Champion Discs
# ..         ...    ...    ...   ...   ...                        ...
# 111     Wombat    5.0      6    -1   0.0      Innova Champion Discs
# 112    Wombat3    5.0      6    -1   0.0      Innova Champion Discs
# 113     Wraith   11.0      5    -1   3.0      Innova Champion Discs
# 114   XCaliber   12.0      5     0   4.0      Innova Champion Discs
# 116       Xero    2.0      3     0   0.0      Innova Champion Discs
#
#     disc_model  max_weight_(gr)  diameter_(cm)  height_(cm)  rim_depth_(cm)  \
# ...

# %%
pairplot = sns.pairplot(df[[
    'speed',
    'glide',
    'turn',
    'fade',
    'diameter_(cm)',
    'height_(cm)',
    'rim_depth_(cm)',
    'inside_rim_diameter_(cm)',
    'rim_thickness_(cm)'
    ]]
)

# %%
sns.countplot(df, x='speed')
# Out:
# <Axes: xlabel='speed', ylabel='count'>

# %%
sns.countplot(df, x='glide')
# Out:
# <Axes: xlabel='glide', ylabel='count'>

# %%
sns.countplot(df, x='turn')
# Out:
# <Axes: xlabel='turn', ylabel='count'>

# %%
sns.countplot(df, x='fade')
# Out:
# <Axes: xlabel='fade', ylabel='count'>

# %%
sns.scatterplot(df, x='rim_thickness_(cm)', y='speed')
# Out:
# <Axes: xlabel='rim_thickness_(cm)', ylabel='speed'>

# %%
corr_matrix = df.select_dtypes(include=['int64', 'float64']).corr()
corr_matrix.iloc[4:, :4].transform(lambda x: x*100)
# Out:
#                                 speed  glide   turn   fade
# max_weight_(gr)                -46.73   4.13  10.37 -25.29
# diameter_(cm)                  -46.25   4.72   9.98 -25.34
# height_(cm)                    -61.45 -23.53  23.67 -39.87
# rim_depth_(cm)                 -64.68 -52.84  40.01 -25.61
# inside_rim_diameter_(cm)       -95.79 -52.45  25.54 -44.64
# rim_thickness_(cm)              97.16  60.04 -27.32  44.55
# rim_depth_/_diameter_ratio_(%) -60.93 -53.74  36.54 -24.26
# rim_configuration              -73.45 -69.97  35.08 -30.13
# flexibility_(kg)                38.97  18.15   0.98  32.64

# %%
sns.heatmap(corr_matrix.iloc[4:, :4].transform(lambda x: x*100), annot=True )
# Out:
# <Axes: >

# %%
from flight_numbers.make_plots import make_correlation_plot

make_correlation_plot(corr_matrix=corr_matrix)
# Out:
# <Axes: title={'left': 'Flight Numbers and their Physical Characteristics'}>
