# %%
from flight_numbers.get_data import get_innova_data, get_pdga_data, config

# %%
print(config)
# Out:
# {'project': {'name': 'flight_numbers', 'description': 'Data analysis pipeline for customer behavior', 'authors': ['Kevin Havis']}, 'paths': {'data_dir': 'data/', 'raw_data': '${paths.data_dir}/raw', 'processed_data': '${paths.data_dir}/processed', 'innova_url': 'https://www.innovadiscs.com/disc-golf-discs/disc-comparison/', 'innova_table': 'disc-comparison', 'pdga_url': 'https://www.pdga.com/technical-standards/equipment-certification/discs/export'}}

# %%
innova_df = get_innova_data()
pdga_df = get_pdga_data()
# Out:
# /Users/kevinhav/projects/d606_final_project/flight_numbers/get_data.py:38: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_html(str(table))[0]

# %%
pdga_df.head()
# Out:
#   Manufacturer / Distributor    Disc Model  Max Weight (gr)  Diameter (cm)  \
# 0             Lone Star Disc  Prickly Pear            176.0           21.2
# 1                Yikun Discs  Wù Kōng (悟空)            176.0           21.2
# 2                Yikun Discs   Bái Zé (白泽)            176.0           21.2
# 3                Yikun Discs   Né Zhā (哪吒)            179.3           21.6
# 4     Discape Disc Golf Inc.      Draconyx            175.1           21.1
#
#    Height (cm)  Rim Depth (cm)  Inside Rim Diameter (cm)  Rim Thickness (cm)  \
# 0          1.8             1.3                      19.0                 1.1
# 1          1.9             1.1                      17.3                 2.0
# 2          1.9             1.1                      17.7                 1.8
# 3          1.8             1.2                      18.9                 1.4
# 4          1.5             1.2                      17.2                 2.0
#
# ...

# %%
innova_df.head()
# Out:
#         DISC  SPEED  GLIDE  TURN  FADE ABBR.
# 0       Aero    3.0      6     0   0.0    AE
# 1      Alien    4.0      2     0   1.0   NaN
# 2     Animal    2.0      1     0   1.0   NaN
# 3        Ape   13.0      5     0   4.0   APE
# 4  Archangel    8.0      6    -4   1.0    AA
