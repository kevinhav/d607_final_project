# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import flight_numbers.get_data

pd.set_option('display.max_columns', None)

# %%
pdga = flight_numbers.get_data.get_pdga_data()

# %%
pdga_clean = flight_numbers.get_data.clean_pdga_data(pdga)

# %%
pdga_clean
# Out:
#      manufacturer_/_distributor  \
# 0                Lone Star Disc
# 1                   Yikun Discs
# 2                   Yikun Discs
# 3                   Yikun Discs
# 4        Discape Disc Golf Inc.
# ...                         ...
# 2126               Wham-O, Inc.
# 2127               Wham-O, Inc.
# 2128               Wham-O, Inc.
# 2129               Wham-O, Inc.
# 2130               Wham-O, Inc.
#
#                                              disc_model  max_weight_(gr)  \
# 0                                          Prickly Pear            176.0
# 1                                          Wù Kōng (悟空)            176.0
# 2                                           Bái Zé (白泽)            176.0
# 3                                           Né Zhā (哪吒)            179.3
# 4                                              Draconyx            175.1
# ...                                                 ...              ...
# 2126  165g (80, 81, 81C, 81E, 82E & 900 molds & High...            200.0
# 2127  Super Pro (no #, 50, 60, 61, 61N, 61B, 62, 62N...            200.0
# 2128                               Fastback (all molds)            196.7
# 2129                                             Master            200.0
# 2130  Professional (1, 4, 10, 14, 15, 16, 17, 20, 20...            198.4
#
#       diameter_(cm)  height_(cm)  rim_depth_(cm)  inside_rim_diameter_(cm)  \
# 0              21.2          1.8             1.3                      19.0
# 1              21.2          1.9             1.1                      17.3
# 2              21.2          1.9             1.1                      17.7
# 3              21.6          1.8             1.2                      18.9
# 4              21.1          1.5             1.2                      17.2
# ...             ...          ...             ...                       ...
# 2126           26.9          3.1             1.9                      25.7
# 2127           25.5          2.8             1.8                      24.3
# 2128           23.7          2.8             1.7                      22.4
# 2129           27.5          3.2             1.8                      26.0
# 2130           23.9          3.0             1.7                      22.7
#
#       rim_thickness_(cm)  rim_depth_/_diameter_ratio_(%)  rim_configuration  \
# 0                    1.1                             6.1              58.50
# 1                    2.0                             5.2              32.25
# 2                    1.8                             5.2              33.75
# 3                    1.4                             5.6              44.75
# 4                    2.0                             5.7              29.25
# ...                  ...                             ...                ...
# 2126                 0.6                             7.1              94.75
# 2127                 0.6                             7.1              86.00
# 2128                 0.6                             7.2              79.50
# 2129                 0.7                             6.5              83.75
# 2130                 0.6                             7.1              89.00
#
#       flexibility_(kg)                        class  max_weight_vint_(gr)  \
# 0                 6.02                          NaN                   NaN
# 1                 8.41                          NaN                   NaN
# 2                 9.77                          NaN                   NaN
# 3                 8.07                          NaN                   NaN
# 4                11.93                          NaN                   NaN
# ...                ...                          ...                   ...
# 2126              4.76  Super Class & Vintage Class                 180.2
# 2127              2.38  Super Class & Vintage Class                 170.9
# 2128              2.49  Super Class & Vintage Class                 158.8
# 2129              4.08  Super Class & Vintage Class                 184.3
# 2130              3.18  Super Class & Vintage Class                 160.1
#
#       last_year_production certification_number approved_date
# 0                      NaN               24-216  Nov 11, 2024
# 1                      NaN               24-219  Nov 11, 2024
# 2                      NaN               24-217  Nov 11, 2024
# 3                      NaN               24-218  Nov 11, 2024
# 4                      NaN               24-214  Oct 28, 2024
# ...                    ...                  ...           ...
# 2126                   NaN                74-03   Jan 1, 1974
# 2127                   NaN                73-01   Jan 1, 1973
# 2128                   NaN                71-01   Jan 1, 1971
# 2129                   NaN                67-01   Jan 1, 1967
# 2130                   NaN                64-01   Jan 1, 1964
#
# [2131 rows x 16 columns]

# %%
df = flight_numbers.get_data.get_data()
# Out:
# /Users/kevinhav/projects/d606_final_project/flight_numbers/get_data.py:38: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_html(str(table))[0]

# %%
df
# Out:
#            disc  speed  glide  turn  fade manufacturer_/_distributor  \
# 0          Aero    3.0      6     0   0.0      Innova Champion Discs
# 1         Alien    4.0      2     0   1.0      Innova Champion Discs
# 2        Animal    2.0      1     0   1.0      Innova Champion Discs
# 3           Ape   13.0      5     0   4.0      Innova Champion Discs
# 4     Archangel    8.0      6    -4   1.0      Innova Champion Discs
# ..          ...    ...    ...   ...   ...                        ...
# 113      Wraith   11.0      5    -1   3.0      Innova Champion Discs
# 114    XCaliber   12.0      5     0   4.0      Innova Champion Discs
# 115          XD    3.0      4    -1   1.0                        NaN
# 116        Xero    2.0      3     0   0.0      Innova Champion Discs
# 117  Yeti Aviar    2.0      3     0   1.0                        NaN
#
#     disc_model  max_weight_(gr)  diameter_(cm)  height_(cm)  rim_depth_(cm)  \
# 0         Aero            180.1           21.7          2.5             1.3
# 1        Alien            178.5           21.5          2.5             1.5
# 2       Animal            176.0           21.2          2.1             1.3
# 3          Ape            175.1           21.1          1.5             1.2
# 4    Archangel            175.1           21.1          1.9             1.4
# ..         ...              ...            ...          ...             ...
# 113     Wraith            175.1           21.1          1.4             1.2
# 114   XCaliber            175.1           21.1          1.6             1.2
# 115        NaN              NaN            NaN          NaN             NaN
# 116       Xero            176.0           21.2          2.0             1.5
# 117        NaN              NaN            NaN          NaN             NaN
#
#      inside_rim_diameter_(cm)  rim_thickness_(cm)  \
# 0                        19.6                 1.0
# 1                        20.3                 0.6
# 2                        19.2                 1.0
# 3                        16.2                 2.4
# 4                        17.3                 1.8
# ..                        ...                 ...
# 113                      16.9                 2.1
# 114                      16.4                 2.3
# 115                       NaN                 NaN
# 116                      19.2                 1.0
# 117                       NaN                 NaN
#
#      rim_depth_/_diameter_ratio_(%)  rim_configuration  flexibility_(kg)  \
# 0                               6.0              43.75              8.16
# 1                               7.0              82.00              3.30
# 2                               6.1              64.00              9.66
# 3                               5.7              27.75             12.13
# 4                               7.1              31.25              9.19
# ..                              ...                ...               ...
# 113                             5.7              26.75              8.85
# 114                             5.7              29.50              8.85
# 115                             NaN                NaN               NaN
# 116                             7.1              68.75              8.98
# 117                             NaN                NaN               NaN
#
#     class  max_weight_vint_(gr)  last_year_production certification_number  \
# 0     NaN                   NaN                   NaN                83-03
# 1     NaN                   NaN                   NaN               22-228
# 2     NaN                   NaN                   NaN                20-80
# 3     NaN                   NaN                   NaN                11-04
# 4     NaN                   NaN                   NaN                01-06
# ..    ...                   ...                   ...                  ...
# 113   NaN                   NaN                   NaN                05-15
# 114   NaN                   NaN                   NaN                08-09
# 115   NaN                   NaN                   NaN                  NaN
# 116   NaN                   NaN                   NaN               21-126
# 117   NaN                   NaN                   NaN                  NaN
#
#     approved_date
# 0     Jun 1, 1983
# 1    Dec 12, 2022
# 2    Sep 29, 2020
# 3    Feb 18, 2011
# 4    Aug 21, 2001
# ..            ...
# 113  Aug 15, 2005
# 114  Mar 13, 2008
# 115           NaN
# 116  Nov 22, 2021
# 117           NaN
#
# [118 rows x 21 columns]

# %%
pairplot = sns.pairplot(df[[
    'speed',
    'glide',
    'turn',
    'fade',
    'diameter_(cm)',
    'height_(cm)',
    'rim_depth_(cm)',
    'inside_rim_diameter_(cm)',
    'rim_thickness_(cm)'
    ]]
)

# %%
sns.countplot(df, x='speed')
# Out:
# <Axes: xlabel='speed', ylabel='count'>

# %%
sns.countplot(df, x='glide')
# Out:
# <Axes: xlabel='glide', ylabel='count'>

# %%
sns.countplot(df, x='turn')
# Out:
# <Axes: xlabel='turn', ylabel='count'>

# %%
sns.countplot(df, x='fade')
# Out:
# <Axes: xlabel='fade', ylabel='count'>
